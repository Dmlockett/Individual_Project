# %%
# Import the Necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Install Yahoo Finance
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (0.2.32)
# Requirement already satisfied: pandas>=1.3.0 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (2.3.9)
# Requirement already satisfied: peewee>=3.16.2 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/devenlockett/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
#Import yfinance as yf
import yfinance as yf

# %%
#set start and end
start = "2006-01-01"
end = "2023-11-20"

# %%
#Step 3:
#For the Signature Bank stock, you use yahoo finance (yf) and 
# the ticker name symbol "SBNY" for Signature Bank
SBNY = yf.download('SBNY', start, end)

# For the Silicon Valey Bank
SIVBQ = yf.download('SIVBQ', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 4: set the tickers, using the stiker symbol for each Bank
tickers = ['SBNY','SIVBQ']

# %%
# Step 5: Use pandas to combine these two data as one dataframe
stock_df = pd.concat([SBNY,SIVBQ], axis=1, keys=tickers)

# %%
# Setp 6: Check the first five row of these data
stock_df.head()
# Out:
#                  SBNY                                                      \
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-01-03  28.090000  28.620001  27.900000  28.500000  26.421671  377593
# 2006-01-04  28.450001  28.719999  28.290001  28.500000  26.421671  314188
# 2006-01-05  28.299999  28.500000  28.299999  28.400000  26.328960   48196
# 2006-01-06  28.650000  28.790001  28.150000  28.590000  26.505106   90469
# 2006-01-09  28.700001  28.820000  28.469999  28.799999  26.699793   87657
#
#                 SIVBQ
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-01-03  47.270000  47.340000  45.849998  46.549999  46.549999   519084.0
# 2006-01-04  46.330002  46.770000  45.950001  46.130001  46.130001  1026640.0
# 2006-01-05  46.000000  46.400002  45.680000  45.700001  45.700001   581344.0
# 2006-01-06  45.700001  46.810001  45.700001  46.700001  46.700001   762263.0
# 2006-01-09  46.570000  46.799999  46.419998  46.669998  46.669998   456720.0

# %%
# You can plot individual stock. What can you say about the Signature Bank?
SBNY['Open'].plot()
sns.despine()

# %%
# Amazon
AMZ = yf.download('AMZN', start, end)
# Bank of America
BAC = yf.download('BAC', start, end)
# JPMorgan Chase
JPM = yf.download('JPM',start, end)
# City Group
C = yf.download('C',start, end)
# Goldman Sachs
GS = yf.download('GS',start, end)
# Morgan Stanley
MS = yf.download('MS',start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create a list of tickers for thes stocks and call it tickers
tickers = ["AMZ", "BAC", "JPM", "C", "GS", "MS"]

# %%
#use set_option to display all 36 columns of the stocks_df
pd.set_option('display.max_columns', 36)

# %%
stocks_df = pd.concat([AMZ,BAC,C, GS,JPM,MS],axis=1,keys=tickers)
stocks_df.columns.names = ['Bank Ticker','Stock Info']

# %%
# Check the first five rows of the stocks_df
stocks_df.head(5)
# Out:
# Bank Ticker     AMZ                                                     BAC  \
# Stock Info     Open    High     Low   Close Adj Close     Volume       Open
# Date
# 2006-01-03   2.3735  2.3925  2.3125  2.3790    2.3790  151644000  46.919998
# 2006-01-04   2.3745  2.3865  2.3345  2.3625    2.3625  148818000  47.000000
# 2006-01-05   2.3580  2.4100  2.3555  2.3825    2.3825  108344000  46.580002
# 2006-01-06   2.3985  2.4290  2.3660  2.3935    2.3935  123058000  46.799999
# 2006-01-09   2.3275  2.3550  2.3200  2.3540    2.3540  178862000  46.720001
#
# Bank Ticker                                                               JPM  \
# Stock Info        High        Low      Close  Adj Close    Volume        Open
# Date
# 2006-01-03   47.180000  46.150002  47.080002  32.168709  16296700  490.000000
# 2006-01-04   47.240002  46.450001  46.580002  31.827076  17757900  488.600006
# 2006-01-05   46.830002  46.320000  46.639999  31.868048  14970700  484.399994
# 2006-01-06   46.910000  46.349998  46.570000  31.820246  12599800  488.799988
# 2006-01-09   46.970001  46.360001  46.599998  31.840714  15619400  486.000000
#
# Bank Ticker                                                           \
# Stock Info         High         Low       Close   Adj Close   Volume
# Date
# 2006-01-03   493.799988  481.100006  492.899994  338.403137  1537600
# 2006-01-04   491.000000  483.500000  483.799988  332.155640  1870960
# 2006-01-05   487.799988  484.000000  486.200012  333.803314  1143160
# 2006-01-06   489.000000  482.000000  486.200012  333.803314  1370210
# 2006-01-09   487.399994  483.000000  483.899994  332.224304  1680740
#
# Bank Ticker           C                                                 \
# Stock Info         Open        High         Low       Close  Adj Close
# Date
# 2006-01-03   126.699997  129.440002  124.230003  128.869995  98.085457
# 2006-01-04   127.349998  128.910004  126.379997  127.089996  96.730698
# 2006-01-05   126.000000  127.320000  125.610001  127.040001  96.692635
# 2006-01-06   127.290001  129.250000  127.290001  128.839996  98.062637
# 2006-01-09   128.500000  130.619995  128.000000  130.389999  99.242386
#
# Bank Ticker                  GS                                              \
# Stock Info    Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   6188700  39.830002  40.360001  39.299999  40.189999  24.948778
# 2006-01-04   4861600  39.779999  40.139999  39.419998  39.619999  24.804779
# 2006-01-05   3717400  39.610001  39.810001  39.500000  39.740002  24.879925
# 2006-01-06   4319600  39.919998  40.240002  39.549999  40.020000  25.055218
# 2006-01-09   4723500  39.880001  40.720001  39.880001  40.669998  25.462145
#
# Bank Ticker                   MS                                              \
# Stock Info     Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   12838600  57.169998  58.490002  56.740002  58.310001  33.585461
# 2006-01-04   13491500  58.700001  59.279999  58.349998  58.349998  33.608490
# 2006-01-05    8109400  58.549999  58.590000  58.020000  58.509998  33.700661
# 2006-01-06    7966900  58.770000  58.849998  58.049999  58.570000  33.735210
# 2006-01-09   16575200  58.630001  59.290001  58.619999  59.189999  34.092316
#
# Bank Ticker
# Stock Info    Volume
# Date
# 2006-01-03   5377000
# 2006-01-04   7977800
# 2006-01-05   5778000
# 2006-01-06   6889800
# 2006-01-09   4144500

# %%
# Part II. Access all stocks once and call that dataframe stocks.For example: to access Signature Bank and Silcon Valey Bank data,we use
stock_df = yf.download(['SBNY','SIVBQ'],start, end)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Check the first five rows of the dataframe
stock_df.head()
# Out:
#             Adj Close                 Close                  High             \
#                  SBNY      SIVBQ       SBNY      SIVBQ       SBNY      SIVBQ
# Date
# 2006-01-03  26.421671  46.549999  28.500000  46.549999  28.620001  47.340000
# 2006-01-04  26.421671  46.130001  28.500000  46.130001  28.719999  46.770000
# 2006-01-05  26.328960  45.700001  28.400000  45.700001  28.500000  46.400002
# 2006-01-06  26.505106  46.700001  28.590000  46.700001  28.790001  46.810001
# 2006-01-09  26.699793  46.669998  28.799999  46.669998  28.820000  46.799999
#
#                   Low                  Open             Volume
#                  SBNY      SIVBQ       SBNY      SIVBQ    SBNY      SIVBQ
# Date
# 2006-01-03  27.900000  45.849998  28.090000  47.270000  377593   519084.0
# 2006-01-04  28.290001  45.950001  28.450001  46.330002  314188  1026640.0
# 2006-01-05  28.299999  45.680000  28.299999  46.000000   48196   581344.0
# 2006-01-06  28.150000  45.700001  28.650000  45.700001   90469   762263.0
# 2006-01-09  28.469999  46.419998  28.700001  46.570000   87657   456720.0

# %%
# Your code here
stocks = yf.download(["AMZN", "BAC", "JPM", "C", "GS", "MS" ], start, end)
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                          \
#                 AMZN        BAC           C         GS        JPM         MS
# Date
# 2006-01-03    2.3790  32.168709  338.403137  98.085457  24.948778  33.585461
# 2006-01-04    2.3625  31.827076  332.155640  96.730698  24.804779  33.608490
# 2006-01-05    2.3825  31.868048  333.803314  96.692635  24.879925  33.700661
# 2006-01-06    2.3935  31.820246  333.803314  98.062637  25.055218  33.735210
# 2006-01-09    2.3540  31.840714  332.224304  99.242386  25.462145  34.092316
#
#              Close                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03  2.3790  47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04  2.3625  46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05  2.3825  46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06  2.3935  46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09  2.3540  46.599998  483.899994  130.389999  40.669998  59.189999
#
#               High                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03  2.3925  47.180000  493.799988  129.440002  40.360001  58.490002
# 2006-01-04  2.3865  47.240002  491.000000  128.910004  40.139999  59.279999
# 2006-01-05  2.4100  46.830002  487.799988  127.320000  39.810001  58.590000
# 2006-01-06  2.4290  46.910000  489.000000  129.250000  40.240002  58.849998
# 2006-01-09  2.3550  46.970001  487.399994  130.619995  40.720001  59.290001
#
#                Low                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03  2.3125  46.150002  481.100006  124.230003  39.299999  56.740002
#
# Bank Ticker    Open                                                           \
# Stock Info     AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03   2.3735  46.919998  490.000000  126.699997  39.830002  57.169998
# 2006-01-04   2.3745  47.000000  488.600006  127.349998  39.779999  58.700001
# 2006-01-05   2.3580  46.580002  484.399994  126.000000  39.610001  58.549999
# 2006-01-06   2.3985  46.799999  488.799988  127.290001  39.919998  58.770000
# 2006-01-09   2.3275  46.720001  486.000000  128.500000  39.880001  58.630001
#
# Bank Ticker     Volume
# Stock Info        AMZN       BAC        C       GS       JPM       MS
# Date
# 2006-01-03   151644000  16296700  1537600  6188700  12838600  5377000
# 2006-01-04   148818000  17757900  1870960  4861600  13491500  7977800
# 2006-01-05   108344000  14970700  1143160  3717400   8109400  5778000
# 2006-01-06   123058000  12599800  1370210  4319600   7966900  6889800
# 2006-01-09   178862000  15619400  1680740  4723500  16575200  4144500

# %%
# What is the maximum Close Price for each Stock?
#(Hint use the stocks dataframe)
# Your code here

stocks["Close"].max()
# Out:
# Stock Info
# AMZN    186.570496
# BAC      54.900002
# C       564.099976
# GS      423.850006
# JPM     171.779999
# MS      108.730003
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
returns = stocks['Close'].pct_change()

# %%
# Check the first five rows of the returns
returns.head()
# Out:
# Stock Info      AMZN       BAC         C        GS       JPM        MS
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.006936 -0.010620 -0.018462 -0.013812 -0.014183  0.000686
# 2006-01-05  0.008466  0.001288  0.004961 -0.000393  0.003029  0.002742
# 2006-01-06  0.004617 -0.001501  0.000000  0.014169  0.007046  0.001025
# 2006-01-09 -0.016503  0.000644 -0.004731  0.012030  0.016242  0.010586

# %%
returns.idxmin()
# Out:
# Stock Info
# AMZN   2006-07-26
# BAC    2009-01-20
# C      2009-02-27
# GS     2009-01-20
# JPM    2009-01-20
# MS     2008-10-09
# dtype: datetime64[ns]

# %% [markdown]
# Bank of America, Goldman and Sachs, and JP Morgan all have the same worst single day returns on Januart 20, 2009 which is when Barack Obama was innagurated

# %%
returns.idxmax()
# Out:
# Stock Info
# AMZN   2007-04-25
# BAC    2009-04-09
# C      2008-11-24
# GS     2008-11-24
# JPM    2009-01-21
# MS     2008-10-13
# dtype: datetime64[ns]

# %%
# Graph the Close column for each stock in the stocks dataframe 
# that you've created. Is there any relationship between this plot 
# and the worst drop date of these stocks?
#your code here

sns.lineplot(data = stocks["Close"])
# Out:
# <Axes: xlabel='Date'>

# %%
sns.pairplot(data = returns)

# %%
plt.hist(AMZ["Close"], label = "AMZN")
plt.hist(BAC["Close"], label = "BAC")
plt.hist(C["Close"], label = "C")
plt.hist(GS["Close"], label = "GS")
plt.hist(JPM["Close"], label = "JPM")
plt.hist(MS["Close"], label = "MS")
plt.legend()

# %%
JPM['Close']['2006-01-01':'2008-07-01'].rolling(window=30).mean().plot(label='30 Day Avg')
JPM['Close']['2006-01-01':'2008-07-01'].plot(label='JPM CLOSE')

MS['Close']['2006-01-01':'2008-07-01'].rolling(window=30).mean().plot(label='30 Day Avg')
MS['Close']['2006-01-01':'2008-07-01'].plot(label='MS CLOSE')
plt.legend()
